# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mp

# %%
df=pd.read_csv('/home/josephstalin/Downloads/ML & Data Science/assignment/assignment 4/train.csv')
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200

# %%
df['Gender']=df['Gender'].replace(value='Female',to_replace='F')
df['Gender']=df['Gender'].replace(value='Male',to_replace='M')

df.head(100)
# Out:
#     User_ID Product_ID  Gender    Age  Occupation City_Category  \
# 0   1000001  P00069042  Female   0-17          10             A
# 1   1000001  P00248942  Female   0-17          10             A
# 2   1000001  P00087842  Female   0-17          10             A
# 3   1000001  P00085442  Female   0-17          10             A
# 4   1000002  P00285442    Male    55+          16             C
# ..      ...        ...     ...    ...         ...           ...
# 95  1000019  P00251642    Male   0-17          10             A
# 96  1000019  P00244842    Male   0-17          10             A
# 97  1000021  P00220242    Male  18-25          16             B
# 98  1000022  P00351142    Male  18-25          15             A
# 99  1000022  P00213242    Male  18-25          15             A
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# ...

# %%
skewed_data=pd.DataFrame(np.random.exponential(size=10000))
skewed_data.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>
